# %% [markdown]
# # Quantum Circuit Identities
#
# Gavin E. Crooks
#
# 2019-03-08
#
# This notebook illustrates various identities between quantum circuits, using `QuantumFlow`, a toolkit for developing and exporing quantum algorithm on gate-model quantum computer.
#
#  (see https://quantumflow.readthedocs.io/en/latest/, https://github.com/gecrooks/quantumflow)

# %%
import quantumflow as qf
import numpy as np
from IPython.display import Image, display, HTML

# %% [markdown]
# ## Creating and displaying circuits, and verifing circuit identities

# %% [markdown]
# Lets create a simple 2-qubit quantum circuit, and display it.

# %%
circ0 = qf.Circuit()
circ0 += qf.Z(0)            # Z gate on qubit 0
circ0 += qf.CNOT(0, 1)      # Controlled not gate: control is qubit 0, target is qubit 1
qf.circuit_to_image(circ0)  # Convert circuit to LaTex, then to PNG image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=253x92 at 0x120342630>

# %% [markdown]
# We can commute a Z gate past the control of a CNOT gate, so the following circuit is equivalent to the previous circuit.

# %%
circ1 = qf.Circuit()
circ1 += qf.CNOT(0, 1)      # Controlled not gate: control is qubit 0, target is qubit 1
circ1 += qf.Z(0)            # Hadamard gate on qubit 0
qf.circuit_to_image(circ1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=253x92 at 0x1207D1C18>

# %% [markdown]
# Let's prove that statment. We can convert a circuit into the equivelent unitary gate with the `Circuit.asgate()` method, and then measure distances between gates using the Fubini-Study angle. This is a metric distance, and thus zero if and only if the gates (and therefore the original circuits) are identical (Up to phase difference, which does not matter physically).

# %%
qf.gate_angle(circ0.asgate(), circ1.asgate())
# Out:
# 0.0

# %% [markdown]
# The `gates_close()` method returns true if the gates are (almost) equivalent, as measured by the gate angle.

# %%
qf.gates_close(circ0.asgate(), circ1.asgate())
# Out:
# True

# %% [markdown]
# ## Simple circuit identities
# The QuantumFlow examples directory contains a selection of such circuit identities. Let's verify and display these circuit interelations.

# %%
from examples import circuit_identities
def compare_circuits(circ0, circ1):
    assert qf.gates_close(circ0.asgate(), circ1.asgate()) # Double check that identity is true
    qubits = (circ0 + circ1).qubits    # Gather qubits of both circuits
    circ = qf.Circuit()                # Create combined circuit with a gap
    circ += circ0
    circ += qf.I(*qubits)                    # Just show trailing wire
    circ += qf.visualization.NoWire(*qubits) # Add a gap in the circuit
    circ += circ1
    return qf.circuit_to_image(circ)

for description, circ0, circ1 in circuit_identities.identities()[:-4]:
    print(description)
    display(compare_circuits(circ0, circ1))
# Out:
# Hadamard is own inverse
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=364x44 at 0x12081DE80>
# Hadamards convert X to Z
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=455x44 at 0x12081DF98>
# Hadamards convert Z to X
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=455x44 at 0x120342400>
# S sandwich converts X to Y
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=454x47 at 0x12081DF98>
# S sandwich converts Y to X
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=454x47 at 0x120823198>
# Hadamards convert RZ to RX
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=599x50 at 0x120823358>
# Hadamard ZYZ decomposition
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=403x49 at 0x12081DD30>
# CZ to CNOT
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=417x80 at 0x12081DE48>
# CZ to CNOT (2)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=439x85 at 0x1207D19B0>
# SWAP to 3 CNOTs
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x82 at 0x12081DF28>
# SWAP to 3 CZs
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=598x102 at 0x1207D19B0>
# ISWAP decomposition to SWAP and CNOT
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=588x102 at 0x120823518>
# ISWAP decomposition to SWAP and CZ
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=451x102 at 0x1208239B0>
# CNOT sandwich with X on control
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=429x102 at 0x1207D1978>
# CNOT sandwich with Z on target
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x102 at 0x12081DEB8>
# DCNOT (Double-CNOT) to iSWAP
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=617x108 at 0x120823198>
# Commute X on CNOT target
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=429x80 at 0x12081DDA0>
# Commute X on CNOT control
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=429x102 at 0x12081DE80>
# Commute Z on CNOT target
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x102 at 0x120823320>
# Commute Z on CNOT control
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x92 at 0x12081DDA0>
# Canonical gates: CZ to ZZ
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=395x102 at 0x1208230B8>
# Canonical gates: XX to ZZ
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=525x102 at 0x120823470>
# Canonical gates: CNOT to XX
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=609x108 at 0x12081DF28>
# Canonical gates: SWAP to Canonical
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=412x86 at 0x1208234E0>
# ISWAP to Canonical
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=495x86 at 0x120823358>
# ISWAP to Canonical in Weyl chamber
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=620x102 at 0x12081DEB8>
# DCNOT to Canonical
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=794x108 at 0x1208236D8>
# CNOT controls commute
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=401x118 at 0x120823470>
# CNOT targets commute
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=401x107 at 0x1207D19E8>
# Commutation of CNOT target/control
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=449x118 at 0x1208237F0>
# Indirect CNOT and 4 CNOTS with intermediate qubit
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=480x118 at 0x12081DDA0>
# CZs with shared shared qubit commute
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=353x95 at 0x120823470>
# Toffoli gate CNOT decomposition
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=878x166 at 0x120823898>
# ZZ to CNOTs
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=564x100 at 0x120823B38>
# XX to CNOTs
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=695x108 at 0x120823668>
# XX to CNOTs (2)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=717x114 at 0x120823B70>
# YY to CNOTs
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=717x114 at 0x120823588>
# CPHASE to ZZ
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=656x107 at 0x12081DF28>
